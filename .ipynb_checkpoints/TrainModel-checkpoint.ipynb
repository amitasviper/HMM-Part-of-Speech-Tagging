# %%
import os
import sys
import numpy as np
incrementer = 0.0000000000000001

# %%
def getFileContents(filename):
    data = None
    with open(filename, 'r') as f:
        data = f.readlines()
    return data

# %%
def getFileFromCommandLine():
    filename = sys.argv[1]
    return getFileContents(filename)

# %%
def splitWordTag(word_tag_pair):
    splitted = word_tag_pair.split('/')
    tag = splitted[-1]
    word = '/'.join(splitted[:-1])
    return word, tag

# %%
def getUniqueTags(tagged_data):
    tags = {}
    for line in tagged_data:
        word_tag_pairs = line.strip().split(' ')
        for word_tag_pair in word_tag_pairs:
            word, tag = splitWordTag(word_tag_pair)
            if tag in tags.keys():
                tags[tag] += 1
            else:
                tags[tag] = 1
    return tags

# %%
def getOpenProbabilities(tagged_data, all_tags_dict):
    global incrementer
    sentences_count = len(tagged_data)
    open_tag_count_dict = {}
    for line in tagged_data:
        first_word_tag_pairs = line.strip().split(' ')[0]
        word, tag = splitWordTag(first_word_tag_pairs)
        if tag in open_tag_count_dict.keys():
            open_tag_count_dict[tag] += 1
        else:
            open_tag_count_dict[tag] = 1
    
    #increment all existing tags count to one
    open_tag_count_dict.update((tag, occurances + incrementer) for tag, occurances in open_tag_count_dict.items())
    sentences_count += (sentences_count*incrementer)
    
    #add one two non-opening tags
    for tag in all_tags_dict.keys():
        try:
            val = open_tag_count_dict[tag]
        except KeyError as e:
            open_tag_count_dict[tag] = incrementer
            sentences_count += incrementer
    
    open_tag_count_dict.update((tag, (occurances*1.0)/sentences_count) for tag, occurances in open_tag_count_dict.items())
    return open_tag_count_dict

# %%
def getCloseProbabilities(tagged_data, all_tags_dict):
    global incrementer
    sentences_count = len(tagged_data)
    close_tag_count_dict = {}
    for line in tagged_data:
        last_word_tag_pairs = line.strip().split(' ')[-1]
        word, tag = splitWordTag(last_word_tag_pairs)
        if tag in close_tag_count_dict.keys():
            close_tag_count_dict[tag] += 1
        else:
            close_tag_count_dict[tag] = 1
            
    #increment all existing tags count to one
    close_tag_count_dict.update((tag, occurances + incrementer) for tag, occurances in close_tag_count_dict.items())
    sentences_count += (sentences_count*incrementer)
    
    #add one two non-closing tags
    for tag in all_tags_dict.keys():
        try:
            val = close_tag_count_dict[tag]
        except KeyError as e:
            close_tag_count_dict[tag] = incrementer
            sentences_count += incrementer
            
    close_tag_count_dict.update((tag, (occurances*1.0)/sentences_count) for tag, occurances in close_tag_count_dict.items())
    return close_tag_count_dict

# %%
def buildTransitionMatrix(tagged_data, tags_dict):
    global incrementer
    tags = tags_dict.keys()
    tags.sort()
    
    tags_index_dict = {}
    for index, tag in enumerate(tags):
        tags_index_dict[tag] = index
    
    tag_count = len(tags)
    
    #Change this line to np.ones for add 1 smoothing
    transition_matrix = np.zeros(shape=(tag_count, tag_count))
    
    for line in tagged_data:
        prev_tag = None
        word_tag_pairs = line.strip().split(' ')
        
        for word_tag_pair in word_tag_pairs:
            word, tag = splitWordTag(word_tag_pair)
            
            if prev_tag is not None:
                transition_matrix[tags_index_dict[prev_tag]][tags_index_dict[tag]] += 1
            
            prev_tag = tag
            
    transition_matrix = transition_matrix + incrementer
    probability_transition_matrix = transition_matrix/transition_matrix.sum(axis=1, keepdims=True)
    probability_transition_matrix[np.isnan(probability_transition_matrix)] = 0
    return probability_transition_matrix, tags_index_dict

# %%
def getUniqueWords(tagged_data):
    words = []
    for line in tagged_data:
        word_tag_pairs = line.strip().split(' ')
        
        for word_tag_pair in word_tag_pairs:
            word, tag = splitWordTag(word_tag_pair)
            words.append(word)
    return list(set(words))

# %%
def computeEmissionProbabilities(tagged_data, tags_dict):
    global incrementer
    tags = tags_dict.keys()
    tags.sort()
    
    words = getUniqueWords(tagged_data)
    words.sort()
    
    tags_index_dict = {}
    for index, tag in enumerate(tags):
        tags_index_dict[tag] = index
        
    words_index_dict = {}
    for index, word in enumerate(words):
        words_index_dict[word] = index
    
    tag_count = len(tags)
    word_count = len(words)
    
    # word_count + 1 => Last column for unseen words
    emission_matrix = np.zeros(shape=(tag_count, word_count + 1))
    
    for line in tagged_data:
        prev_tag = None
        word_tag_pairs = line.strip().split(' ')
        
        for word_tag_pair in word_tag_pairs:
            word, tag = splitWordTag(word_tag_pair)
            
            emission_matrix[tags_index_dict[tag]][words_index_dict[word]] += 1
            
            prev_tag = tag
    #increment 1 in all the elements so that the last col for unseen words have non zero values
    emission_matrix = emission_matrix + incrementer
    probability_emission_matrix = emission_matrix/emission_matrix.sum(axis=1, keepdims=True)
    probability_emission_matrix[np.isnan(probability_emission_matrix)] = 0
    return probability_emission_matrix, tags_index_dict, words_index_dict

# %%
def printEmissionProbabilities(count):
    counter = 0
    global probability_emission_matrix, tags_index_dict, words_index_dict
    word_count = len(words_index_dict.keys())
    tag_count = len(tags_index_dict.keys())
    for word, word_index in words_index_dict.iteritems():
        for tag, tag_index in tags_index_dict.iteritems():
            if probability_emission_matrix[tag_index][word_index] != 0:
                print tag, " => ", word, ' => ', probability_emission_matrix[tag_index][word_index]
                counter += 1
                if counter > count:
                    return

# %%
unseen_words = {}
def getMostProbableTags(sentence):
    global opening_probabilities, closing_probabilities, probability_transition_matrix, probability_emission_matrix, tags_index_dict, words_index_dict
    global tag_count, unseen_words
    
    sentence_words = sentence.strip().split(' ')
    
    sentence_len = len(sentence_words)
    
    viterbi_matrix = np.zeros(shape=(tag_count, sentence_len))
    
    tracing_matrix = [[None for x in range(sentence_len)] for y in range(tag_count)]
    
    for word_index in range(sentence_len):
        word = sentence_words[word_index]
        for model_tag, model_tag_index in tags_index_dict.iteritems():
            
            try:
                word_emission_probability = probability_emission_matrix[model_tag_index][words_index_dict[word]]
            except KeyError as e:
                word_emission_probability = probability_emission_matrix[model_tag_index][-1]
                try:
                    unseen_words[word] += 1
                except KeyError as e:
                    unseen_words[word] = 1
                
            
            if word_index == 0:
                try:
                    tag_opening_probability = opening_probabilities[model_tag]
                except KeyError as e:
                    print "tag_opening_probability : Keyerror encountered"
                    tag_opening_probability = 1.1754943508222875e-10
                viterbi_matrix[model_tag_index][word_index] = tag_opening_probability * word_emission_probability
            else:
                max_probability = -1
                max_tag = None
                for prev_model_tag, prev_model_tag_index in tags_index_dict.iteritems():
                    tag_transition_probability = probability_transition_matrix[prev_model_tag_index][model_tag_index]
                    if tag_transition_probability == 0.0:
                        print "Transition probability still zero"
                        tag_transition_probability = 1.1754943508222875e-10
                    temp_probability = viterbi_matrix[prev_model_tag_index][word_index-1] * tag_transition_probability * word_emission_probability  
                    if temp_probability > max_probability:
                        max_probability = temp_probability
                        max_tag = prev_model_tag
                        
                viterbi_matrix[model_tag_index][word_index] = max_probability
                tracing_matrix[model_tag_index][word_index] = max_tag
    
    max_probability = -1
    max_probability_tag = None
    for model_tag, model_tag_index in tags_index_dict.iteritems():
        temp_probability = 0.0
        try:
            tag_closing_probabilities = closing_probabilities[model_tag]
        except KeyError as e:
            print "tag_closing_probabilities : Keyerror encountered", 
            tag_closing_probabilities = 1.1754943508222875e-10
        temp_probability =  tag_closing_probabilities * viterbi_matrix[model_tag_index][sentence_len-1]
        if temp_probability > max_probability:
            max_probability = temp_probability
            max_probability_tag = model_tag

    assigned_tags = [max_probability_tag]
    current_best_tag = max_probability_tag
    for col in range(sentence_len-1, 0, -1):
        current_best_tag = tracing_matrix[tags_index_dict[current_best_tag]][col]
        assigned_tags.append(current_best_tag)
    assigned_tags = assigned_tags[::-1]
    
    anotated_sentence = ''
    for index, assigned_tag in enumerate(assigned_tags):
        anotated_sentence += str(sentence_words[index]) + '/' + str(assigned_tag) + ' '
    
    
    return anotated_sentence.strip()

# %%
tagged_data = getFileContents('data/en_train_tagged.txt')
tags_dict = getUniqueTags(tagged_data)

# %%
opening_probabilities = getOpenProbabilities(tagged_data, tags_dict)
closing_probabilities = getCloseProbabilities(tagged_data, tags_dict)

# %%
probability_transition_matrix, tags_index_dict = buildTransitionMatrix(tagged_data, tags_dict)

# %%
probability_emission_matrix, tags_index_dict, words_index_dict = computeEmissionProbabilities(tagged_data, tags_dict)

# %%
printEmissionProbabilities(5)
# Out:
# PRP$  =>  Unemployent  =>  3.25945241199e-20
# VBG  =>  Unemployent  =>  3.003003003e-20
# FW  =>  Unemployent  =>  1.0752688172e-18
# NFP  =>  Unemployent  =>  2.95857988166e-19
# ``  =>  Unemployent  =>  1.23001230012e-19
# VBN  =>  Unemployent  =>  2.52143217347e-20

# %%
tag_count = len(tags_index_dict.keys())

# %%
# %load_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
# sentence = "Bush also nominated A. Noel Anketell Kramer for a 15 - year term as associate judge of the District of Columbia Court of Appeals , replacing John Montague Steadman ."
sentence = "The sheikh in wheel - chair has been attacked with a F - 16 - launched bomb ."
# sentence = "the Pakistan military"
getMostProbableTags(sentence)
# Out:
# 'The/DT sheikh/JJS in/IN wheel/NN -/HYPH chair/NN has/VBZ been/VBN attacked/VBN with/IN a/DT F/NNP -/HYPH 16/CD -/HYPH launched/VBN bomb/NN ./.'

# %%
dev_tagged_data = getFileContents('data/en_dev_tagged.txt')
dev_untagged_data = getFileContents('data/en_dev_raw.txt')

# %%
correct = 0
total = 0
for index, test_line in enumerate(dev_untagged_data):
    predicted_tagged_line = getMostProbableTags(test_line)
    expected_tagged_line = dev_tagged_data[index]
    predicted_word_tag_pairs = predicted_tagged_line.strip().split(' ')
    expected_word_tag_pairs = expected_tagged_line.strip().split(' ')
    for index, predicted_word in enumerate(predicted_word_tag_pairs):
        if predicted_word == expected_word_tag_pairs[index]:
            correct += 1
        total += 1
        if total % 100 == 0:
            print correct, total, " => ", (correct*100.0)/total
accuracy = (correct*100.0)/total
print accuracy
# Out:
# 85 100  =>  85.0
# 178 200  =>  89.0
# 267 300  =>  89.0
# 357 400  =>  89.25
# 452 500  =>  90.4
# 539 600  =>  89.8333333333
# 628 700  =>  89.7142857143
# 717 800  =>  89.625
# 803 900  =>  89.2222222222
# 895 1000  =>  89.5
# 984 1100  =>  89.4545454545
# 1071 1200  =>  89.25
# 1163 1300  =>  89.4615384615
# 1240 1400  =>  88.5714285714
# 1324 1500  =>  88.2666666667
# 1418 1600  =>  88.625
# 1506 1700  =>  88.5882352941
# 1595 1800  =>  88.6111111111
# 1685 1900  =>  88.6842105263
# 1777 2000  =>  88.85
# 1863 2100  =>  88.7142857143
# 1951 2200  =>  88.6818181818
# 2045 2300  =>  88.9130434783
# 2133 2400  =>  88.875
# 2230 2500  =>  89.2
# 2314 2600  =>  89.0
# 2403 2700  =>  89.0
# 2490 2800  =>  88.9285714286
# 2582 2900  =>  89.0344827586
# 2668 3000  =>  88.9333333333
# 2758 3100  =>  88.9677419355
# 2845 3200  =>  88.90625
# 2933 3300  =>  88.8787878788
# 3015 3400  =>  88.6764705882
# 3104 3500  =>  88.6857142857
# 3189 3600  =>  88.5833333333
# 3281 3700  =>  88.6756756757
# 3367 3800  =>  88.6052631579
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# Yes
# 3455 3900  =>  88.5897435897
# 3546 4000  =>  88.65
# 3642 4100  =>  88.8292682927
# 3738 4200  =>  89.0
# 3825 4300  =>  88.9534883721
# 3915 4400  =>  88.9772727273
# 3995 4500  =>  88.7777777778
# 4080 4600  =>  88.6956521739
# 4167 4700  =>  88.6595744681
# 4261 4800  =>  88.7708333333
# 4339 4900  =>  88.5510204082
# 4425 5000  =>  88.5
# 4506 5100  =>  88.3529411765
# 4590 5200  =>  88.2692307692
# 4677 5300  =>  88.2452830189
# 4764 5400  =>  88.2222222222
# 4851 5500  =>  88.2
# 4936 5600  =>  88.1428571429
# 5029 5700  =>  88.2280701754
# 5113 5800  =>  88.1551724138
# 5195 5900  =>  88.0508474576
# 5289 6000  =>  88.15
# 5364 6100  =>  87.9344262295
# 5451 6200  =>  87.9193548387
# 5534 6300  =>  87.8412698413
# 5610 6400  =>  87.65625
# 5685 6500  =>  87.4615384615
# 5772 6600  =>  87.4545454545
# 5860 6700  =>  87.4626865672
# 5952 6800  =>  87.5294117647
# 6032 6900  =>  87.4202898551
# 6102 7000  =>  87.1714285714
# 6182 7100  =>  87.0704225352
# 6271 7200  =>  87.0972222222
# 6359 7300  =>  87.1095890411
# 6450 7400  =>  87.1621621622
# 6530 7500  =>  87.0666666667
# 6616 7600  =>  87.0526315789
# 6708 7700  =>  87.1168831169
# 6796 7800  =>  87.1282051282
# 6885 7900  =>  87.1518987342
# 6982 8000  =>  87.275
# 7075 8100  =>  87.3456790123
# 7163 8200  =>  87.3536585366
# 7252 8300  =>  87.3734939759
# 7339 8400  =>  87.369047619
# 7419 8500  =>  87.2823529412
# 7496 8600  =>  87.1627906977
# 7571 8700  =>  87.0229885057
# 7644 8800  =>  86.8636363636
# 7724 8900  =>  86.7865168539
# 7809 9000  =>  86.7666666667
# 7877 9100  =>  86.5604395604
# 7956 9200  =>  86.4782608696
# 8046 9300  =>  86.5161290323
# 8137 9400  =>  86.5638297872
# 8235 9500  =>  86.6842105263
# 8311 9600  =>  86.5729166667
# 8406 9700  =>  86.6597938144
# 8493 9800  =>  86.6632653061
# 8584 9900  =>  86.7070707071
# 8677 10000  =>  86.77
# 8773 10100  =>  86.8613861386
# 8855 10200  =>  86.8137254902
# 8944 10300  =>  86.8349514563
# 9030 10400  =>  86.8269230769
# 9100 10500  =>  86.6666666667
# 9173 10600  =>  86.5377358491
# 9259 10700  =>  86.5327102804
# 9343 10800  =>  86.5092592593
# 9435 10900  =>  86.5596330275
# 9525 11000  =>  86.5909090909
# 9613 11100  =>  86.6036036036
# 9708 11200  =>  86.6785714286
# 9800 11300  =>  86.7256637168
# 9894 11400  =>  86.7894736842
# 9982 11500  =>  86.8
# 10061 11600  =>  86.7327586207
# 10138 11700  =>  86.6495726496
# 10231 11800  =>  86.7033898305
# 10313 11900  =>  86.6638655462
# 10399 12000  =>  86.6583333333
# 10490 12100  =>  86.694214876
# 10578 12200  =>  86.7049180328
# 10667 12300  =>  86.7235772358
# 10755 12400  =>  86.7338709677
# 10831 12500  =>  86.648
# 10889 12600  =>  86.4206349206
# 10974 12700  =>  86.4094488189
# 11042 12800  =>  86.265625
# 11129 12900  =>  86.2713178295
# 11218 13000  =>  86.2923076923
# 11292 13100  =>  86.1984732824
# 11385 13200  =>  86.25
# 11471 13300  =>  86.2481203008
# 11551 13400  =>  86.2014925373
# 11630 13500  =>  86.1481481481
# 11721 13600  =>  86.1838235294
# 11811 13700  =>  86.2116788321
# 11899 13800  =>  86.2246376812
# 11982 13900  =>  86.2014388489
# 12070 14000  =>  86.2142857143
# 12154 14100  =>  86.1985815603
# 12244 14200  =>  86.2253521127
# 12325 14300  =>  86.1888111888
# 12417 14400  =>  86.2291666667
# 12506 14500  =>  86.2482758621
# 12594 14600  =>  86.2602739726
# 12671 14700  =>  86.1972789116
# 12756 14800  =>  86.1891891892
# 12841 14900  =>  86.1812080537
# 12930 15000  =>  86.2
# 13010 15100  =>  86.1589403974
# 13097 15200  =>  86.1644736842
# 13178 15300  =>  86.1307189542
# 13265 15400  =>  86.1363636364
# 13351 15500  =>  86.135483871
# 13441 15600  =>  86.1602564103
# 13524 15700  =>  86.1401273885
# 13603 15800  =>  86.0949367089
# 13688 15900  =>  86.0880503145
# 13779 16000  =>  86.11875
# 13865 16100  =>  86.1180124224
# 13946 16200  =>  86.0864197531
# 14037 16300  =>  86.1165644172
# 14125 16400  =>  86.1280487805
# 14213 16500  =>  86.1393939394
# 14302 16600  =>  86.156626506
# 14394 16700  =>  86.1916167665
# 14480 16800  =>  86.1904761905
# 14563 16900  =>  86.1715976331
# 14654 17000  =>  86.2
# 14743 17100  =>  86.216374269
# 14830 17200  =>  86.2209302326
# 14908 17300  =>  86.1734104046
# 14997 17400  =>  86.1896551724
# 15087 17500  =>  86.2114285714
# 15172 17600  =>  86.2045454545
# 15260 17700  =>  86.2146892655
# 15344 17800  =>  86.202247191
# 15432 17900  =>  86.2122905028
# 15517 18000  =>  86.2055555556
# 15603 18100  =>  86.2044198895
# 15687 18200  =>  86.1923076923
# 15755 18300  =>  86.0928961749
# 15833 18400  =>  86.0489130435
# 15920 18500  =>  86.0540540541
# 16008 18600  =>  86.064516129
# 16092 18700  =>  86.0534759358
# 16175 18800  =>  86.0372340426
# 16259 18900  =>  86.0264550265
# 16349 19000  =>  86.0473684211
# 16429 19100  =>  86.0157068063
# 16522 19200  =>  86.0520833333
# 16615 19300  =>  86.0880829016
# 16706 19400  =>  86.1134020619
# 16798 19500  =>  86.1435897436
# 16892 19600  =>  86.1836734694
# 16984 19700  =>  86.2131979695
# 17074 19800  =>  86.2323232323
# 17160 19900  =>  86.2311557789
# 17250 20000  =>  86.25
# 17335 20100  =>  86.2437810945
# 17413 20200  =>  86.202970297
# 17502 20300  =>  86.2167487685
# 17589 20400  =>  86.2205882353
# 17672 20500  =>  86.2048780488
# 17757 20600  =>  86.1990291262
# 17842 20700  =>  86.193236715
# 17926 20800  =>  86.1826923077
# 18011 20900  =>  86.1770334928
# 18101 21000  =>  86.1952380952
# 18187 21100  =>  86.1943127962
# 18279 21200  =>  86.2216981132
# 18367 21300  =>  86.2300469484
# 18454 21400  =>  86.2336448598
# 18539 21500  =>  86.2279069767
# 18628 21600  =>  86.2407407407
# 18722 21700  =>  86.2764976959
# 18808 21800  =>  86.2752293578
# 18889 21900  =>  86.2511415525
# 18974 22000  =>  86.2454545455
# 19063 22100  =>  86.257918552
# 19147 22200  =>  86.2477477477
# 19233 22300  =>  86.2466367713
# 19319 22400  =>  86.2455357143
# 19412 22500  =>  86.2755555556
# 19504 22600  =>  86.3008849558
# 19592 22700  =>  86.3083700441
# 19684 22800  =>  86.3333333333
# 19774 22900  =>  86.3493449782
# 19864 23000  =>  86.3652173913
# 19947 23100  =>  86.3506493506
# 20028 23200  =>  86.3275862069
# 20115 23300  =>  86.330472103
# 20197 23400  =>  86.311965812
# 20289 23500  =>  86.3361702128
# 20380 23600  =>  86.3559322034
# 20464 23700  =>  86.3459915612
# 20553 23800  =>  86.3571428571
# 20636 23900  =>  86.3430962343
# 20731 24000  =>  86.3791666667
# 20822 24100  =>  86.398340249
# 20910 24200  =>  86.4049586777
# 21001 24300  =>  86.4238683128
# 21088 24400  =>  86.4262295082
# 21176 24500  =>  86.4326530612
# 21269 24600  =>  86.4593495935
# 21360 24700  =>  86.4777327935
# 21456 24800  =>  86.5161290323
# 21542 24900  =>  86.5140562249
# 21630 25000  =>  86.52
# 21724 25100  =>  86.5498007968
# 86.5675202799

# %%
unseen_words
# Out:
# {'NYT': 50,
#  'Abbas': 500,
#  'perverted': 100,
#  'Imbalance': 100,
#  'Foundation': 50,
#  'Hangout': 50,
#  'calculate': 100,
#  'insurgencies': 50,
#  'punjab': 100,
#  'Jennings': 50,
#  'Sewell': 50,
#  'Shirley': 50,
#  'ergo': 50,
#  'Fix': 50,
#  'GT': 50,
#  'HANO': 300,
#  'communique': 50,
#  'sellers': 100,
#  'GG': 50,
#  'digic': 50,
#  'crops': 50,
#  'relentlessly': 50,
#  'unrelated': 50,
#  'notifying': 50,
#  'Malach': 50,
#  '29th': 50,
#  'W.H.S.': 50,
#  'Matthew': 100,
#  'crave': 100,
#  'http://www.4gamer.net/news/image/2005.09/20050917034321_2big.html': 50,
#  'julie...@bellsouth.net': 50,
#  'Townsend': 50,
#  'pander': 50,
#  'revolutionize': 50,
#  'asia': 100,
#  'pinchers': 50,
#  'Amazon': 50,
#  'Newsgroups': 100,
#  'coefficient': 50,
#  'statehood': 50,
#  'meh': 50,
#  'Sts.': 50,
#  'Curry': 50,
#  'conversational': 50,
#  'Adz': 100,
#  'luggage': 50,
#  'auction': 50,
#  'Surprisingly': 50,
#  'TJO': 50,
#  'jill': 50,
#  'browsing': 50,
#  'redevelopment': 50,
#  'Harvey': 50,
#  '9/30/01': 50,
#  'Reverting': 50,
#  'Epic': 100,
#  'Drugs': 50,
#  'sweater': 50,
#  'coins': 50,
#  'asses': 100,
#  'annotations': 50,
#  'Ste': 50,
#  'mired': 50,
#  'http://www.thecatalbum.com': 50,
#  'Normally': 50,
#  'tampa': 50,
#  'Mery': 50,
#  '3200': 50,
#  'mi': 50,
#  'Habib': 100,
#  'Achilles': 50,
#  'GummiBear': 50,
#  'appologies': 50,
#  'india': 50,
#  'Awsome': 50,
#  'ONe': 50,
#  'Masoud': 50,
#  'organizer': 50,
#  'loathe': 50,
#  'ceremony': 50,
#  'LD': 50,
#  'U.S': 100,
#  'hoc': 100,
#  'writers': 50,
#  'Gretchen': 50,
#  'raffle': 50,
#  'blanks': 100,
#  'Lisa_resume.doc': 100,
#  'Neoconservatives': 50,
#  'suing': 50,
#  'pigment': 50,
#  '09:11': 50,
#  'Civic': 50,
#  'Calzones': 50,
#  'CALL': 50,
#  'Aquire': 50,
#  'Quinn': 50,
#  'plumbing': 50,
#  'Speak': 100,
#  'Saginaw': 50,
#  'L.P.': 50,
#  'Hills': 100,
#  'Housing': 250,
#  'Alternate': 50,
#  'fab': 100,
#  'Newsgroup': 100,
#  'Hilla': 50,
#  'sludge': 50,
#  'Ordinary': 50,
#  'Jackass': 50,
#  'baiting': 50,
#  'http://www.4gamer.net/news/image/2005.09/20050917024918_1big.html': 50,
#  'Urban': 100,
#  'chihuahua': 100,
#  'http://home.enron.com/employeemeeting': 50,
#  'Argentinian': 50,
#  'Helen': 50,
#  'Dorn': 50,
#  'Challenge': 50,
#  'Simulation': 50,
#  'Staikos': 50,
#  'mimicking': 50,
#  'Specialized': 100,
#  'grammar': 50,
#  'rocky': 50,
#  'potatoes': 50,
#  'heures': 50,
#  'volcano': 50,
#  'dumpy': 50,
#  'Cockatiels': 50,
#  'consolidate': 50,
#  'Kasna': 50,
#  'HORSE': 50,
#  'pueble': 50,
#  'Destiny': 50,
#  'enthusiasts': 50,
#  'goldconn@isye.gatech.edu': 50,
#  'aide': 50,
#  'Benitez': 50,
#  'Scharffen': 50,
#  'saturday': 50,
#  'Shaalan': 50,
#  'Saab': 50,
#  'strangers': 50,
#  'HMB': 50,
#  'Doda': 50,
#  '10/08/99': 50,
#  'http://www.bbc.co.uk/news': 50,
#  'fave': 50,
#  'amstel': 50,
#  'hoodia': 50,
#  'Steadman': 50,
#  'Hollister': 50,
#  'enlightened': 50,
#  'AFP': 50,
#  '05/22/2001': 50,
#  'r2': 50,
#  'Carri': 50,
#  'Photo': 50,
#  'Servers': 100,
#  'silicon': 50,
#  'PADDIIstocksCL.pdf': 100,
#  'corrections': 50,
#  'Bridges': 50,
#  'www.adobe.com': 50,
#  'McDonal': 50,
#  '03/23/2001': 50,
#  'marisol': 50,
#  'TEHRAN': 50,
#  'Cozy': 50,
#  'overstating': 50,
#  '5.76': 50,
#  'Hanson': 50,
#  'Zionists': 50,
#  'filibuster': 50,
#  'transmittal': 200,
#  'YAY': 50,
#  'http://discountairlineticket.blogspot.com/2005/10/some-techniques-to-...': 50,
#  'bacon': 50,
#  'Qaida': 100,
#  'predictable': 100,
#  'unfertilized': 50,
#  'Fun': 100,
#  'somone': 50,
#  'Natasha': 50,
#  'discriminated': 50,
#  'coward': 50,
#  'forensic': 100,
#  'http://www.accenture.com': 50,
#  'Crap': 50,
#  'smoker': 50,
#  'ible': 50,
#  'seamstress': 50,
#  'laden': 50,
#  'davidr...@optonline.net': 50,
#  'subjects': 100,
#  'appetitie': 50,
#  'Ash': 50,
#  'recordkeeping': 50,
#  'caricatures': 50,
#  'Edible': 50,
#  'Knight': 50,
#  'Resolving': 50,
#  'wells': 50,
#  'memorabilia': 50,
#  'Adelia': 50,
#  'Warrick': 50,
#  'Meal': 150,
#  'Jacques': 50,
#  'NiMo': 200,
#  'ragnarok': 50,
#  'Brilll': 50,
#  'Want': 50,
#  'abouts': 50,
#  'planetary': 50,
#  'Flash': 50,
#  'RobBrnglsn@aol.com': 50,
#  'endowment': 50,
#  'Urchin': 50,
#  'Wrong': 50,
#  'hrs': 50,
#  'unleashed': 50,
#  'Huwaijah': 50,
#  'knuckle': 100,
#  'Brant': 100,
#  'http://www.usatoday.com/tech/science/space/2005-03-09-nasa-search_x.htm?csp=34': 50,
#  'Atmosphere': 100,
#  'Roadways': 50,
#  'da': 50,
#  'ect.': 50,
#  'dp': 100,
#  'Deco': 50,
#  'Totally': 100,
#  '85,000': 50,
#  'intervals': 50,
#  'architecture': 50,
#  'grilled': 50,
#  'Partners': 50,
#  'PS.': 50,
#  'Methodists': 50,
#  'habit': 50,
#  'motherboard': 50,
#  'Burch': 50,
#  'guerre': 100,
#  'Butler': 50,
#  'Caoimhe': 50,
#  'Gurgaon': 50,
#  'embroidery': 50,
#  'Microdermabrasions': 50,
#  'irc': 100,
#  'Ratcliff': 50,
#  'suckups': 50,
#  'smelled': 100,
#  'Nasser': 100,
#  'fisrt': 50,
#  'rreynol...@cogeco.ca': 50,
#  'Against': 50,
#  'adage': 50,
#  '281.848.1619': 50,
#  'horsemen': 50,
#  'cos': 50,
#  'Pledge': 50,
#  'cow': 50,
#  'Covert': 50,
#  'PSA': 50,
#  'Demented': 50,
#  'HCA': 50,
#  'C\xc3\xa9cile': 50,
#  'CLOSED': 50,
#  'Euros': 150,
#  '!!!!!!!!!!!!!?': 50,
#  'PIRAMAR': 50,
#  'bureaucratic': 50,
#  'union': 50,
#  'condemned': 100,
#  'http://en.wikipedia.org/wiki/Cubism': 50,
#  'trusting': 50,
#  '@paulhastings.com': 50,
#  '3-5213': 50,
#  'sooooo': 100,
#  'CURES': 50,
#  'heartland': 100,
#  'Arabists': 50,
#  'sadists': 50,
#  'Constellation': 100,
#  'Sadrists': 50,
#  'florida': 50,
#  'mexico': 100,
#  'prettty': 50,
#  'Write': 50,
#  'ALWAY': 50,
#  'anticipating': 50,
#  'sells': 50,
#  'Georgetown': 50,
#  'DR': 50,
#  'Seaview': 50,
#  'Peder': 50,
#  'speculating': 50,
#  'Graae': 50,
#  'Steffen': 50,
#  'Roof': 50,
#  'maime': 50,
#  'HPL': 50,
#  'tune': 50,
#  'arab': 50,
#  '1977': 50,
#  'thr': 50,
#  'http://www.bbc.co.uk/email': 50,
#  '3-5076': 50,
#  'ssome': 50,
#  'Mobil': 50,
#  'Griffin': 200,
#  'bellow': 50,
#  'rodent': 50,
#  'transporting': 50,
#  '235-1972': 50,
#  'hireing': 50,
#  'enlighten': 50,
#  '07:17': 50,
#  'shoul': 50,
#  'Kufa': 50,
#  'spasms': 50,
#  'Baqubah': 50,
#  'twinky': 50,
#  'Milson': 50,
#  'Vangie.McGilloway@powersrc.com': 50,
#  '______________________': 50,
#  'natal': 100,
#  'Gerard': 50,
#  'Uncensored': 100,
#  '==============================================================================': 100,
#  'Certain': 50,
#  's100': 50,
#  'securities': 50,
#  '203.674.7723': 50,
#  'CCNG': 100,
#  'Responsive': 50,
#  'Unconfirmed': 50,
#  'Caldwell': 50,
#  'predominance': 50,
#  'excerpt': 50,
#  'malaysia': 50,
#  'intern': 100,
#  'Conservation': 50,
#  'LeT': 50,
#  "O'Keefe": 50,
#  'Puto': 50,
#  'gtownsend@manorisd.net': 50,
#  'Villega': 100,
#  'Griffith@ENRON': 50,
#  'Choudhry': 50,
#  'Quite': 50,
#  'Les': 50,
#  'Calls': 50,
#  'ply': 50,
#  'buffet': 100,
#  'Chowk': 100,
#  'poss': 50,
#  'TEXT.htm': 150,
#  '_____': 50,
#  "o'neal": 50,
#  'curry': 50,
#  'beacuse': 50,
#  'Muqtada': 200,
#  'Fed': 50,
#  'Blacks': 50,
#  'donated': 50,
#  'raises': 50,
#  'oolong': 50,
#  'ADHD': 50,
#  '03/27/2001': 100,
#  'Hank': 100,
#  "c'est": 50,
#  'extrememly': 50,
#  'GNOFHAC': 100,
#  'wavering': 50,
#  'tacky': 50,
#  'Z': 150,
#  '220': 50,
#  'veiled': 50,
#  'staged': 50,
#  'Beer': 50,
#  'liens': 100,
#  'RAVIZ': 50,
#  'Engineering': 50,
#  'ded69...@hotmail.com': 50,
#  'submitting': 50,
#  'attn': 50,
#  'plaintiffs': 50,
#  'arabes': 100,
#  'strengthening': 50,
#  'Josh': 50,
#  'http://www.4gamer.net/news/image/2005.09/20050919032951_42big.html': 50,
#  'lunde': 50,
#  'Squares': 50,
#  'Bryngelson': 50,
#  'solicitation': 50,
#  'pledging': 50,
#  'Traci': 300,
#  'Vladi': 150,
#  'preceding': 50,
#  "let's": 50,
#  'nymex': 50,
#  'scores': 50,
#  'franz371...@gmail.com': 150,
#  'derail': 50,
#  'admidst': 50,
#  'Radical': 50,
#  'vietnam': 50,
#  'Mass': 50,
#  'mismanaged': 50,
#  'skis': 50,
#  'bombed': 100,
#  'themes': 50,
#  ':?': 150,
#  '08:52': 50,
#  'Gets': 50,
#  'Boyle': 50,
#  '4gamer': 50,
#  'depend': 50,
#  'mis-matches': 50,
#  'flash': 50,
#  'counter-attack': 50,
#  'Figaro': 50,
#  'macho': 50,
#  'adviser': 100,
#  'smartphone': 50,
#  'Tech': 150,
#  'Barrel': 100,
#  'blast': 50,
#  'tortillas': 50,
#  'www.thecatalbum.com': 50,
#  'http://www.4gamer.net/news/image/2005.09/20050919032951_41big.html': 50,
#  'Mateo': 50,
#  'soooo': 50,
#  'Mcmanus': 50,
#  'Mahmoud': 200,
#  'speculation': 100,
#  'fearing': 50,
#  'Nova': 50,
#  'API.pdf': 100,
#  '05:09': 50,
#  'thinker': 50,
#  'Heritage': 50,
#  'Rodale': 100,
#  'pedi': 50,
#  'cosy': 50,
#  'nightie': 50,
#  'hymn': 250,
#  'Bert': 50,
#  'peiod': 50,
#  '++++++++++++++++++': 50,
#  'anecdotes': 50,
#  'mall': 50,
#  'alt.animals.eagle.bald': 50,
#  'unrestricted': 50,
#  'appeal': 50,
#  'slot': 50,
#  'Darin': 200,
#  'Mo': 50,
#  'Mi': 50,
#  'Webb': 50,
#  '08:28': 50,
#  'tropics': 50,
#  'Dead': 50,
#  '212-848-8400': 50,
#  'releif': 50,
#  '08:14:00': 50,
#  '9/26/2005': 50,
#  'emerge': 50,
#  'substitution': 50,
#  '3-3264': 50,
#  'Jong': 50,
#  'SCULPTURE': 50,
#  'Tammi': 50,
#  '10:13': 50,
#  'indie': 50,
#  'iphone': 50,
#  'UnleadedStocks.pdf': 100,
#  '---=': 100,
#  'Processes': 50,
#  'Ashtamudi': 50,
#  'S100': 100,
#  'Hayes': 50,
#  'legnth': 50,
#  'Lied': 50,
#  'http://www.4gamer.net/news/image/2005.09/20050919032951_21big.html': 50,
#  'harmonious': 50,
#  'incidents': 50,
#  'ferry': 100,
#  'slightest': 100,
#  'portals': 50,
#  'Symphony': 100,
#  'Encino': 50,
#  'listens': 50,
#  'Natzi': 50,
#  'Diaries': 50,
#  '0.3931': 50,
#  '203.961.7523': 50,
#  'checklists': 50,
#  'flavored': 50,
#  'inputs': 50,
#  'Valero': 50,
#  'crashed': 50,
#  'Blooming': 50,
#  'Model': 50,
#  'surfing': 50,
#  'candles': 50,
#  'Sources': 50,
#  'sm': 50,
#  'tutoring': 100,
#  'sf': 50,
#  'se': 50,
#  'Impressed': 50,
#  'unsolicited': 50,
#  'http://explorer.msn.com': 50,
#  'Samarra': 50,
#  'Breaking': 100,
#  'midnight': 50,
#  '?????????????????????????????????????????????????????????': 50,
#  'soing': 50,
#  'Rd': 50,
#  'experiments': 50,
#  'cola': 50,
#  'conjunct': 50,
#  'Greater': 200,
#  'Noida': 350,
#  'Unlimited': 100,
#  'Wesley': 50,
#  'LU': 50,
#  'artisan': 50,
#  'Semantics': 50,
#  'unforchunitly': 50,
#  'Muhammed': 50,
#  'devastated': 50,
#  '1955': 50,
#  'aspected': 50,
#  'Roma': 100,
#  'Marlene': 100,
#  'Khalil': 50,
#  '12:42:55': 50,
#  'Ghulam': 50,
#  'furnishing': 50,
#  'Attendees': 50,
#  'eh': 100,
#  'Goldstar.com': 50,
#  'Stops': 50,
#  'breakthrough': 50,
#  '08/10/2000': 50,
#  'Frazier': 50,
#  'album': 50,
#  '5250': 50,
#  'webmas...@globelingerie.com': 50,
#  'questionsand': 50,
#  'blu': 50,
#  'Welcome': 100,
#  'Saturn': 100,
#  'Mohiuddin': 50,
#  'RFP': 150,
#  'over-eater': 50,
#  'auhtority': 50,
#  'http://cambridgefoodfrivolity.blogspot.com/': 50,
#  'california': 50,
#  'NTKB': 50,
#  'http://unitedway.enron.com': 50,
#  'seakness': 100,
#  'cadmium': 50,
#  'yum': 50,
#  'Birdies': 50,
#  'Alternates': 50,
#  'adorabledelia6...@gmail.com': 50,
#  'suspend': 100,
#  'Gottlieb': 100,
#  'hairstyles': 50,
#  'http://www.4gamer.net/news/image/2005.09/20050919032951_39big.html': 50,
#  '0.1171': 50,
#  '22th': 50,
#  'Mozilla': 400,
#  'Problems': 50,
#  'SEE': 50,
#  'structures': 100,
#  'inefficient': 50,
#  'CLA': 50,
#  'Lisa_coverletter.doc': 100,
#  'Stylish': 50,
#  'thai': 50,
#  'http://www.4gamer.net/news/image/2005.09/20050920111900_21big.html': 50,
#  '6400': 50,
#  'Pizzas': 50,
#  'gte114t@prism.gatech.edu': 50,
#  'eschewing': 50,
#  'sx40': 50,
#  'siding': 50,
#  'www.visitsouthshropshire.co.uk': 50,
#  'DM': 50,
#  'mated': 50,
#  'san': 100,
#  'Hinze': 50,
#  'DD': 50,
#  'occupies': 50,
#  'rained': 50,
#  'lurking': 50,
#  'allen': 50,
#  'Themselves': 100,
#  'nazi': 50,
#  'Houseboat': 50,
#  'SOMEONE': 50,
#  'vangie.mcgilloway@powersrc.com': 50,
#  'terrific': 50,
#  'Phx': 50,
#  'interior': 50,
#  'Dp': 100,
#  'jungle': 50,
#  'Pets': 50,
#  'woodrow': 50,
#  'Allison': 50,
#  'Wong': 50,
#  'trivandrum': 50,
#  'Boone': 50,
#  'administartion': 50,
#  'Auditorium': 50,
#  'Elmira': 100,
#  're-wording': 50,
#  'stockings': 50,
#  'slope': 100,
#  'drastically': 50,
#  'restraunts': 50,
#  'rambling': 50,
#  'german': 50,
#  'reinvigorate': 50,
#  'contemporary': 50,
#  'scarce': 50,
#  'enthusiast': 50,
#  'Officiol': 50,
#  'Wo': 50,
#  'foward': 50,
#  'enriched': 50,
#  'Solar': 50,
#  'Interesting': 50,
#  'revisionist': 50,
#  'Applied': 50,
#  'viewpoint': 50,
#  'VINGAS': 50,
#  'ammazing': 50,
#  'Zahar': 50,
#  'stroll': 50,
#  'Amir': 50,
#  '********************************': 50,
#  'reveal': 50,
#  'Ice': 50,
#  'Lenhart': 50,
#  'Fucking': 50,
#  'floods': 50,
#  '11/16/2005': 50,
#  'influnced': 50,
#  '==----': 100,
#  'YET': 50,
#  'reveals': 50,
#  'Sheetal': 50,
#  'seak': 50,
#  'Kudos': 50,
#  'contactable': 50,
#  'Britt': 100,
#  'satisfying': 100,
#  '3/9/2005': 50,
#  '4105SF': 50,
#  'teacup': 50,
#  'Aggregate': 50,
#  'J.M.': 50,
#  'Neocons': 100,
#  'amplifiaed': 50,
#  'reigns': 50,
#  'Constance': 50,
#  'TODAY': 50,
#  'Cinema': 50,
#  'darin': 50,
#  'blasts': 50,
#  'D\xc3\xa9j\xc3\xa0': 50,
#  'Rahu': 250,
#  'Lizzie': 50,
#  'chorizo': 50,
#  'grooming': 50,
#  '08/15/2000': 100,
#  '12:05': 50,
#  'Delaware': 100,
#  'Janabi': 50,
#  'Interested': 100,
#  '410-468-3499': 50,
#  'pod': 100,
#  'Leader': 50,
#  '66.80': 50,
#  'specializing': 50,
#  'subscribed': 50,
#  'deposited': 50,
#  'Newsday': 50,
#  'peaking': 50,
#  'WANTS': 50,
#  'Catriona': 50,
#  'straigthforward': 50,
#  'Phil': 100,
#  'Posts': 50,
#  'homely': 50,
#  '************************************************': 100,
#  '08:02': 50,
#  '_________________________________________________________________': 50,
#  'Kang': 50,
#  'profiled': 50,
#  'abducted': 50,
#  'Fiji': 250,
#  '=---': 100,
#  'Slice': 100,
#  'sincere': 50,
#  'Nimitz': 50,
#  'clutter': 50,
#  'Lovley': 50,
#  'heirs': 50,
#  'Wellywood': 50,
#  'theyy': 50,
#  "12's": 50,
#  'mane': 50,
#  'closest': 100,
#  '713.306.7940': 50,
#  'Seattlepi.com': 50,
#  'weed': 50,
#  'WashPost': 50,
#  'mani': 50,
#  'climbing': 50,
#  'Vangie': 100,
#  "O'Neill": 50,
#  'Buses': 100,
#  'Miramir': 50,
#  'PADDIstocksHO.pdf': 100,
#  'Chahine': 150,
#  'justify': 100,
#  'Runar': 50,
#  'Woodland': 50,
#  'recycled': 50,
#  'storming': 50,
#  'Pleasure': 50,
#  'TOVA': 50,
#  'kerala': 150,
#  'Motorsports': 50,
#  'Keyhole': 50,
#  'hotdogs': 50,
#  'Diffusion': 50,
#  'hover': 50,
#  'noida': 100,
#  '\\\\': 50,
#  'http://www.4gamer.net/news/image/2005.09/20050919032951_40big.html': 50,
#  'amd': 50,
#  'ire': 50,
#  'McGilloway': 100,
#  'stunt': 50,
#  'amt': 50,
#  'SVP': 50,
#  'valentine': 50,
#  '11:16:00': 50,
#  'Authorised': 50,
#  'Pie': 50,
#  'lightning': 50,
#  'blackberry': 50,
#  'ALTERNATIVE': 50,
#  'anti-smoker': 50,
#  'Perry': 50,
#  'simulator': 50,
#  'ewww': 50,
#  'Brandon': 50,
#  'Baiji': 50,
#  'Sloan': 50,
#  'cabs': 50,
#  'Chillicothe': 50,
#  'cavity': 50,
#  'chromium': 50,
#  'Men': 50,
#  'Met': 50,
#  'naborhood': 50,
#  'anyplace': 50,
#  'Preuss': 50,
#  'internship': 50,
#  '!?????!!!!': 50,
#  'commment': 50,
#  '12/26/2004': 50,
#  'Beauty': 50,
#  '375': 50,
#  'brittany': 50,
#  'BCAA': 50,
#  'escalating': 50,
#  'HTP': 50,
#  'sry': 50,
#  'fallacy': 50,
#  'Lavo': 50,
#  'outlook': 50,
#  'SOblander@carrfut.com': 50,
#  'anothers': 50,
#  'instruments': 50,
#  'gare': 50,
#  'Goodger': 50,
#  'Promotional': 50,
#  'End': 50,
#  'http://www.smooth-on.com/p132/Beginner-Brushable-Mold-Rubber-Options/pages.html': 50,
#  '5233': 50,
#  'brute': 50,
#  'Weed': 50,
#  'Phunnarungsi': 50,
#  'strikes': 150,
#  'cottage': 100,
#  'Derbyshire': 50,
#  'Duty': 50,
#  'Rudwell': 100,
#  '410-468-3798': 50,
#  'IUCN': 50,
#  'grass': 50,
#  'CrudeStocks.pdf': 100,
#  'Efficient': 50,
#  'arises': 50,
#  'Hop': 150,
#  '0.0585': 50,
#  'az': 50,
#  'Ginny': 50,
#  'cream': 100,
#  'amendments': 50,
#  '4.6': 150,
#  '4.0': 100,
#  'idiot': 50,
#  'Cigar': 50,
#  'Omaha': 50,
#  'endeavors': 50,
#  'Payments': 50,
#  'laudatory': 50,
#  "DM's": 50,
#  'restraunt': 50,
#  'bilateral': 50,
#  'waived': 50,
#  'cpa': 50,
#  'wifi': 200,
#  '04/26/2001': 50,
#  'directors': 50,
#  'blouvard': 50,
#  'behavioral': 50,
#  'directory': 50,
#  'essay': 50,
#  'Brokering': 50,
#  'suburban': 50,
#  'kestrel': 50,
#  'http://lingerie.selectedsex.com': 50,
#  'Nasrallah': 150,
#  'Deposited': 50,
#  '4783': 50,
#  'sung': 50,
#  'alcatraz': 50,
#  'lols': 50,
#  'cliff': 50,
#  'auckland': 50,
#  'freewheeling': 50,
#  'dressing': 50,
#  'norm': 50,
#  'clubbed': 50,
#  'chameleon': 150,
#  'Sale': 50,
#  'Soooo': 50,
#  'vacationing': 50,
#  'purrs': 50,
#  'hamburguers': 100,
#  'cable': 100,
#  'Retire': 50,
#  'sang': 50,
#  'lisa': 50,
#  'fm78': 50,
#  'knowledgement': 50,
#  'Hilliard': 100,
#  'Stochastic': 50,
#  'sue': 50,
#  'cues': 50,
#  'Sungjoo': 100,
#  'crush': 50,
#  'Drs.': 50,
#  'gottlie...@yahoo.com': 50,
#  'Pepsi': 100,
#  'fractional': 50,
#  'bislas': 50,
#  'Kliotech': 50,
#  'INDUSTRIAL': 50,
#  'installations': 50,
#  'GISB': 300,
#  'LTD.': 50,
#  '21202': 50,
#  'siamese': 50,
#  'http://www.google.com/search?aq=0&oq=crazy+horse+mem&gcx=w&sourceid=chrome&ie=UTF-8&q=crazy+horse+memorial': 50,
#  'supplements': 50,
#  'freelance': 50,
#  'Shojai': 100,
#  'Album': 150,
#  'Aug': 50,
#  'Jolene': 50,
#  'Reader': 100,
#  'Truly': 50,
#  'Froomkin': 50,
#  'Explorer': 150,
#  'musems': 50,
#  'governance': 50,
#  'pearl': 50,
#  'Kevin.A.Boone@accenture.com': 50,
#  'amenities': 50,
#  'Peak': 50,
#  'gorgeous': 50,
#  'PRESIDENT': 50,
#  'yuck': 50,
#  'Shropshire': 50,
#  'Midtown': 50,
#  'Scudeiros': 50,
#  'browned': 50,
#  'mounted': 50,
#  'FMs': 50,
#  'Sam3102.doc': 50,
#  '++': 50,
#  'sfig...@houston.rr.com': 50,
#  'Elyse': 50,
#  'Mustang': 50,
#  'Pimenov': 50,
#  'spontaneous': 50,
#  'Phantom': 50,
#  'Different': 50,
#  'memoirs': 150,
#  'expeditiously': 100,
#  'Mulholland': 50,
#  'Orchestra': 100,
#  'Thompson': 50,
#  '0.0022': 50,
#  'cubism': 150,
#  'hamburgers': 50,
#  'non-Microsoft': 50,
#  'maps': 50,
#  'Bonding': 50,
#  'earnings': 50,
#  'goat': 50,
#  'simplicity': 50,
#  'plllz': 50,
#  'spectacularly': 50,
#  'http://www.budgieresearch.com': 50,
#  'backyard': 50,
#  'Sophie': 50,
#  'Firangs': 50,
#  'Concessionaire': 50,
#  '??.': 50,
#  'Player': 50,
#  'Sean': 150,
#  'WENSDAY': 50,
#  'Tellechea': 50,
#  'Marathon': 50,
#  'Dial': 50,
#  'Arial': 100,
#  '06:23': 50,
#  'Nervous': 50,
#  'MIX': 50,
#  'islad': 50,
#  'helm': 50,
#  'kollam': 100,
#  'clashed': 50,
#  'fined': 50,
#  'botched': 50,
#  'AOL': 50,
#  'Putting': 50,
#  'Opposition': 50,
#  'fines': 50,
#  'Anketell': 50,
#  'dailyem...@ebs.bbc.co.uk': 50,
#  'sucking': 50,
#  'libido': 50,
#  'Cracker': 50,
#  'Weblog': 50,
#  'hoot': 50,
#  'oone': 50,
#  'Erm': 50,
#  'propter': 50,
#  'Rafael': 100,
#  'Secure': 100,
#  'frequented': 50,
#  'Brownian': 50,
#  'IPO': 50,
#  'Accenture': 50,
#  'unitedway.enron.com': 50,
#  'GOOGLEZON': 50,
#  'Debra': 950,
#  'Zelikow': 50,
#  'connect': 50,
#  'Passport': 50,
#  'silky': 50,
#  'Armando': 50,
#  '10MM': 50,
#  'ENRON@enronXgate': 50,
#  'http://www.google.co.uk/search?q=forensic+photography&ie=utf-8&oe=utf-8&aq=t&rls=org.mozilla:en-US:official&client=firefox-a&safe=active&sout=1': 50,
#  'Cheerleading': 50,
#  'ENRON-CPS': 50,
#  'Intercept': 50,
#  'longtime': 50,
#  'ARTICLE': 50,
#  'Netscape': 50,
#  'Cool': 50,
#  'Mall': 50,
#  'imaging': 50,
#  ...}
